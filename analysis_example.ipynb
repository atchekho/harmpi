# %%
# %run -i harm_script.py

# %%
 rg("gdump")

# %%
 rd("dump000")

# %%
 print(t)
# Out:
# 0.0

# %%
  plt.loglog(r[:,ny//2,0], rho[:,ny//2,0])
  plt.xlabel(r"$r$")
  plt.ylabel(r"$\rho$")
# Out:
# Text(0, 0.5, '$\\rho$')

# %%
plco(np.log10(rho),xy=1,xmax=100,ymax=50,cb=True,isfilled=1,nc=100)
plt.xlabel(r"$x\ [r_\text{g}]$")
plt.ylabel(r"$z\ [r_\text{g}]$")
# Out:
# Text(0, 0.5, '$z\\ [r_\\text{g}]$')

# %%
number_of_dumps = len(glob.glob('dumps/dump[0-9]*'))
for i in np.arange(number_of_dumps):
    print("Processing dump%03d..." % i)
    rd("dump%03d" % i)
    plco(np.log10(rho),xy=1,xmax=100,ymax=50,cb=True,isfilled=1,nc=100)
    plt.savefig("frame%03d.png" % i, dpi=300)
# Out:
# Processing dump000...
# Processing dump001...
# Processing dump002...
# Processing dump003...
# Processing dump004...
# Processing dump005...
# Processing dump006...
# Processing dump007...
# Processing dump008...
# Processing dump009...
# Processing dump010...
# Processing dump011...
# Processing dump012...
# Processing dump013...
# Processing dump014...
# Processing dump015...
# Processing dump016...
# Processing dump017...
# Processing dump018...
# Processing dump019...
# Processing dump020...
# Processing dump021...
# Processing dump022...
# Processing dump023...
# Processing dump024...
# Processing dump025...
# Processing dump026...
# Processing dump027...
# Processing dump028...
# Processing dump029...
# Processing dump030...
# Processing dump031...
# Processing dump032...
# Processing dump033...
# Could not find dump033 or its MPI counterpart
# Processing dump034...
# Could not find dump034 or its MPI counterpart

# %% [markdown]
# Use this for Windows with ffmpeg installed in Windows Subsystem for Linux

# %%
# !wsl ffmpeg -fflags +genpts -r 10 -pattern_type glob -i "frame*.png" -vcodec mpeg4 -qmax 5 movie.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %% [markdown]
# Use this for running in Linux or Mac OSX

# %%
# !ffmpeg -fflags +genpts -r 10 -pattern_type glob -i "frame*.png" -vcodec mpeg4 -qmax 5 movie.mp4

# %%
plco(np.log10(rho),xy=1,cb=True,isfilled=1,nc=100)
psi = psicalc()
plc(psi,xy=1,xmax=40,ymax=20,colors="black")

# %%
rho, ug, uu[1:4], B[1:4]
